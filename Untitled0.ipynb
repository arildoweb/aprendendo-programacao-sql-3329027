# %% [markdown]
# <a href="https://colab.research.google.com/github/arildoweb/aprendendo-programacao-sql-3329027/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Texto de título predefinido
def saudacao(nome):
  print(f'Oi {nome}, vamos estudar')
